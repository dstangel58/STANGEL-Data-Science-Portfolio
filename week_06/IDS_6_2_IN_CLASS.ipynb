# %% [markdown]
# ## Section 1: Combining Data

# %% [markdown]
# Additional examples of [data wrangling in Pandas](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# ### `pd.concat()`
# - **Purpose**: Combines multiple DataFrames into one.
#
# - **Key Parameter**:
#     - `ignore_index`: When set to `True` resets the index so that the resulting DataFrame has a new continuous index.

# %%
import pandas as pd

# Department 1 data
df_dept1 = pd.DataFrame({
    'EmployeeID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Michael'],
    'Department': ['Sales', 'Sales', 'Sales'],
    'Salary': [60000, 62000, 61000]
})

# Department 2 data
df_dept2 = pd.DataFrame({
    'EmployeeID': [104, 105],
    'Name': ['David', 'Henry'],
    'Department': ['Marketing', 'Marketing'],
    'Salary': [65000, 67000]
})
df_employees = pd.concat([df_dept1,df_dept2], ignore_index = True)
print("Combined DataFrame:")
print(df_employees)
# Out:
# Combined DataFrame:
#    EmployeeID     Name Department  Salary
# 0         101    Alice      Sales   60000
# 1         102      Bob      Sales   62000
# 2         103  Michael      Sales   61000
# 3         104    David  Marketing   65000
# 4         105    Henry  Marketing   67000

# %% [markdown]
# ### `rename()`
# - **Purpose**: Changes column names to more meaningful or standardized labels.
# - **Key Parameter**:
#     - `columns`: A dictionary mapping old column names to new names.

# %%
# Rename columns to more descriptive names
df_employees_renamed = df_employees.rename(columns={
    'EmployeeID':'Emp_ID',
    'Name': 'Employee_Name',
    'Department':'Dept',
    'Salary':'Annual_Salary'})
print("\nRenamed DataFrame:")
print(df_employees_renamed)
# Out:
# Renamed DataFrame:
#    Emp_ID Employee_Name       Dept  Annual_Salary
# 0     101         Alice      Sales          60000
# 1     102           Bob      Sales          62000
# 2     103       Michael      Sales          61000
# 3     104         David  Marketing          65000
# 4     105         Henry  Marketing          67000

# %% [markdown]
# ### `sort_values()`
# - **Purpose**: Sorts the DataFrame by a specific column.
# - **Key Parameter**:
#     - `by`: Specifies the column(s) to sort by.
#     - `ascending`: When set to `False` sorts the data in descending order.

# %%
# Sort by Annual_Salary in descending order
df_sorted = df_employees_renamed.sort_values(by='Annual_Salary', ascending=False)
print("\nDataFrame Sorted by Annual Salary (Descending):")
print(df_sorted)
# Out:
# DataFrame Sorted by Annual Salary (Descending):
#    Emp_ID Employee_Name       Dept  Annual_Salary
# 4     105         Henry  Marketing          67000
# 3     104         David  Marketing          65000
# 1     102           Bob      Sales          62000
# 2     103       Michael      Sales          61000
# 0     101         Alice      Sales          60000

# %% [markdown]
# ## Section 2: Method Chaining

# %% [markdown]
# ### **Concept**: Combining several DataFrame operations into one continuous expression.
#
# ### **Advantages**:
# - Improves readability and conciseness.
# - Reduces the need for intermediate variables.
#
# ### Steps in this chain:
# - **Concatenation**: Merges the two department DataFrames.
# - **Renaming**: Standardizes column names.
# - **Sorting**: Orders the DataFrame by annual salary in descending order.

# %%
import pandas as pd

# Department 1 data
df_dept1 = pd.DataFrame({
    'EmployeeID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Michael'],
    'Department': ['Sales', 'Sales', 'Sales'],
    'Salary': [60000, 62000, 61000]
})

# Department 2 data
df_dept2 = pd.DataFrame({
    'EmployeeID': [104, 105],
    'Name': ['David', 'Henry'],
    'Department': ['Marketing', 'Marketing'],
    'Salary': [65000, 67000]
})

# Method chaining: Combine, rename, and sort in descending order of salary.

# %% [markdown]
# ## Group Activity: Cleaning an Untidy Sales Dataset Using Method Chaining

# %% [markdown]
# ### Method Chaining Instructions:
# - Remove duplicates.
# - Fill missing values with 0.
# - Reshape the DataFrame from wide to long format.
# - Sort the final DataFrame.

# %%
import pandas as pd

df_sales = pd.DataFrame({
    'Product': [
        'Widget A', 'Widget B', 'Widget A', 'Widget C',
        'Widget B', 'Widget A', 'Widget D', 'Widget E',
        'Widget C', 'Widget D', 'Widget B', 'Widget E'
    ],
    'Region': [
        'North', 'South', 'North', 'East',
        'South', 'North', 'West', 'East',
        'Central', 'North', 'West', 'South'
    ],
    'Sales_Q1': [100, 200, 100, 150, None, 100, 180, 210, 140, 190, 205, 220],
    'Sales_Q2': [110, None, 110, 160, 210, 110, 185, 220, 150, 200, 215, 230],
    'Sales_Q3': [105, 205, 105, None, 215, 105, 175, 205, 145, 195, 210, 225],
    'Sales_Q4': [115, 215, 115, 165, 225, None, 190, 215, 155, 205, 220, 235]
})

print("Expanded df_sales DataFrame:")

#print(df_sales)

# Method chaining: Clean the dataset in one pipeline.

df_employees = (
    pd.concat([df_dept1, df_dept2], ignore_index=True)
    .rename(columns={
        'EmployeeID': 'Emp_ID',
        'Name': 'Employee_Name',
        'Department': 'Dept',
        'Salary': 'Annual_Salary'
    })
    .sort_values(by='Annual_Salary', ascending=False)
)
# Out:
# Expanded df_sales DataFrame:

# %%
# Create a pivot table that calculates the sum of sales per Product per Region
df_sales = pd.DataFrame({
    'Product': [
        'Widget A', 'Widget B', 'Widget A', 'Widget C',
        'Widget B', 'Widget A', 'Widget D', 'Widget E',
        'Widget C', 'Widget D', 'Widget B', 'Widget E'
    ],
    'Region': [
        'North', 'South', 'North', 'East',
        'South', 'North', 'West', 'East',
        'Central', 'North', 'West', 'South'
    ],
    'Sales_Q1': [100, 200, 100, 150, None, 100, 180, 210, 140, 190, 205, 220],
    'Sales_Q2': [110, None, 110, 160, 210, 110, 185, 220, 150, 200, 215, 230],
    'Sales_Q3': [105, 205, 105, None, 215, 105, 175, 205, 145, 195, 210, 225],
    'Sales_Q4': [115, 215, 115, 165, 225, None, 190, 215, 155, 205, 220, 235]
})
df_sales_clean = (
    pd.pivot_table(df_sales, values=['Sales_Q1','Sales_Q2','Sales_Q3','Sales_Q4'],
                                index='Product', columns='Region', aggfunc='sum')
    .drop_duplicates(['Product','Region','Sales_Q1','Sales_Q2','Sales_Q3','Sales_Q4'])
    .sort_values(by='AnnualSalary',ascending=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9f/f2r2bq793nqd3zrv8mxk8plm0000gn/T/ipykernel_84136/1291145478.py in ?()
#      17 })
#      18 df_sales_clean = (
#      19     pd.pivot_table(df_sales, values=['Sales_Q1','Sales_Q2','Sales_Q3','Sales_Q4'],
#      20                                 index='Product', columns='Region', aggfunc='sum')
# ---> 21     .drop_duplicates(['Product','Region','Sales_Q1','Sales_Q2','Sales_Q3','Sales_Q4'])
#      22     .sort_values(by='AnnualSalary',ascending=False))
#
# /Applications/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6836
#    6837         inplace = validate_bool_kwarg(inplace, "inplace")
#    6838         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6839
# -> 6840         result = self[-self.duplicated(subset, keep=keep)]
#    6841         if ignore_index:
#    6842             result.index = default_index(len(result))
#    6843
#
# /Applications/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6968         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6969         # key that doesn't exist.
#    6970         diff = set(subset) - set(self.columns)
#    6971         if diff:
# -> 6972             raise KeyError(Index(diff))
#    6973
#    6974         if len(subset) == 1 and self.columns.is_unique:
#    6975             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['Sales_Q2', 'Region', 'Sales_Q1', 'Sales_Q4', 'Product', 'Sales_Q3'], dtype='object')
